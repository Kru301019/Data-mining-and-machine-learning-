# %% [markdown]
# Import the required libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read the dataset and print the first 50 rows

# %%
bank = pd.read_csv("bank.csv")

# %%
Read the dataset and print the first 50 rows

# %%
print(bank.head(50))
# Out:
#     age            job   marital  education default  balance housing loan  \
# 0    30     unemployed   married    primary      no     1787      no   no
# 1    33       services   married  secondary      no     4789     yes  yes
# 2    35     management    single   tertiary      no     1350     yes   no
# 3    30     management   married   tertiary      no     1476     yes  yes
# 4    59    blue-collar   married  secondary      no        0     yes   no
# 5    35     management    single   tertiary      no      747      no   no
# 6    36  self-employed   married   tertiary      no      307     yes   no
# 7    39     technician   married  secondary      no      147     yes   no
# 8    41   entrepreneur   married   tertiary      no      221     yes   no
# 9    43       services   married    primary      no      -88     yes  yes
# 10   39       services   married  secondary      no     9374     yes   no
# 11   43         admin.   married  secondary      no      264     yes   no
# ...

# %%
print(bank.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# How many attributes and instances are in the dataset?

# %%
num_attributes, num_instances = bank.shape

# Print the results
print("Number of attributes (columns):", num_attributes)
print("Number of instances (rows):", num_instances)
# Out:
# Number of attributes (columns): 4521
# Number of instances (rows): 17

# %% [markdown]
# Print the value counts of two attributes.

# %%
#selected_columns = bank[['poutcome']]  # Replace 'Column1' and 'Column2' with your actual column names
#print(selected_columns.value_counts())
age_poutcome_counts = bank.groupby(['age', 'poutcome']).size().reset_index(name='count')
successful_age_groups = age_poutcome_counts[age_poutcome_counts['poutcome'] == 'success']
successful_age_groups
#most_successful_age_group = successful_age_groups['count'].idxmax()
#most_successful_age_group
# Out:
#      age poutcome  count
# 2     21  success      1
# 12    26  success      2
# 15    27  success      3
# 18    28  success      4
# 21    29  success      6
# 24    30  success      1
# 27    31  success      6
# 30    32  success      5
# 33    33  success      2
# 36    34  success      7
# 39    35  success      5
# 42    36  success      5
# 45    37  success      7
# 48    38  success      6
# 51    39  success      2
# 54    40  success      4
# 57    41  success      2
# 60    42  success      2
# 63    43  success      3
# 66    44  success      1
# 69    45  success      2
# 72    46  success      3
# 75    47  success      7
# 78    48  success      3
# 83    50  success      2
# 88    52  success      2
# 91    53  success      5
# 94    54  success      3
# 97    55  success      3
# 100   56  success      1
# 103   57  success      1
# 106   58  success      2
# 109   59  success      3
# 112   60  success      1
# 114   61  success      1
# 115   62  success      1
# ...

# %% [markdown]
# List some of the data characteristics.

# %% [markdown]
# age 34 is most frequently involded
# evidently 36 and 45 age groups were most successful

# %% [markdown]
# How many missing values are in the dataset?

# %%
bank.isnull()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
bank_null = pd.isnull(bank["contact"])
bank_null
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 4516    False
# 4517     True
# 4518    False
# 4519    False
# 4520    False
# Name: contact, Length: 4521, dtype: bool

# %% [markdown]
# Using the replace function, replace NaN in the contact attribute with unknown

# %%
bank["contact"].fillna("not available",inplace = True)

# %%
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# Display the count of each marital status.

# %%
bank.groupby(['marital']).size().reset_index(name='count')
# Out:
#     marital  count
# 0  divorced    528
# 1   married   2797
# 2    single   1196
